# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv("C:\\Users\\Dell\\campusx_badhiya_wala_project_isi_folder_me_sab_h\\gurgaon_properties_cleaned_v2.csv").drop_duplicates()

# %%
df.head()
# Out:
#   property_type                      society      sector  price  \
# 0          flat                 ss residency    sector 6   0.48
# 1          flat  ansal housing highland park  sector 103   1.10
# 2          flat        sapphire eighty three   sector 83   0.65
# 3          flat       unitech the residences   sector 33   1.35
# 4          flat                  m3m capital  sector 113   3.25
#
#    price_per_sqft    area                                       areaWithType  \
# 0          5333.0   900.0                     Carpet area: 100 (83.61 sq.m.)
# 1          6242.0  1762.0  Super Built up area 1762(163.7 sq.m.)Built Up ...
# 2          9286.0   700.0                   Built Up area: 700 (65.03 sq.m.)
# 3          8737.0  1545.0             Super Built up area 1545(143.54 sq.m.)
# 4         14142.0  2298.0                   Carpet area: 2298 (213.49 sq.m.)
#
#    bedRoom  bathroom balcony  floorNum      facing       agePossession  \
# 0        3         2       2       2.0         NaN      Moderately Old
# 1        3         3      3+       7.0  North-East        New Property
# 2        1         1       0       6.0         NaN           Undefined
# 3        3         4       2       8.0  North-East      Moderately Old
# 4        4         4      3+      34.0         NaN  Under Construction
#
#    super_built_up_area  built_up_area  carpet_area  study room  servant room  \
# 0                  NaN            NaN        100.0           0             0
# 1               1762.0         1500.0       1300.0           0             0
# 2                  NaN          700.0          NaN           0             0
# 3               1545.0            NaN          NaN           0             1
# 4                  NaN            NaN       2298.0           1             1
#
#    store room  pooja room  others  furnishing_type  luxury_score
# 0           0           0       0                0            54
# 1           0           0       0                0            87
# 2           0           0       0                0             0
# 3           0           0       0                0            49
# 4           0           1       0                0           115

# %% [markdown]
# ## property_type vs price

# %%
sns.barplot(x=df['property_type'], y=df['price'], estimator=np.median)
# Out:
# <Axes: xlabel='property_type', ylabel='price'>

# %%
sns.boxplot(x=df['property_type'], y=df['price'])
# Out:
# <Axes: xlabel='property_type', ylabel='price'>

# %% [markdown]
# ## property_type vs area

# %%
sns.barplot(x=df['property_type'], y=df['built_up_area'], estimator=np.median)
# Out:
# <Axes: xlabel='property_type', ylabel='built_up_area'>

# %%
sns.boxplot(x=df['property_type'], y=df['built_up_area'])
# Out:
# <Axes: xlabel='property_type', ylabel='built_up_area'>

# %%
# removing that crazy outlier
df = df[df['built_up_area'] != 737147]

# %%
sns.boxplot(x=df['property_type'], y=df['built_up_area'])
# Out:
# <Axes: xlabel='property_type', ylabel='built_up_area'>

# %% [markdown]
# ## property_type vs price_per_sqft

# %%
sns.barplot(x=df['property_type'], y=df['price_per_sqft'], estimator=np.median)
# Out:
# <Axes: xlabel='property_type', ylabel='price_per_sqft'>

# %%
sns.boxplot(x=df['property_type'], y=df['price_per_sqft'])
# Out:
# <Axes: xlabel='property_type', ylabel='price_per_sqft'>

# %%
# check outliers
df[df['price_per_sqft'] > 100000][['property_type','society','sector','price','price_per_sqft','area','areaWithType', 'super_built_up_area', 'built_up_area', 'carpet_area']]
# Out:
#      property_type                      society     sector  price  \
# 107          house         bhim nagar, sector 6   sector 6   0.85
# 243          house            vatika india next  sector 82   7.00
# 276          house                  independent  sector 57   8.00
# 344          house                  independent  sector 38   8.00
# 456          house                  independent  sector 23   2.80
# 600          house  unitech nirvana birch court  sector 50   7.10
# 686          house                        ansal  sector 43   1.85
# 804          house                  independent  sector 12   3.50
# 1323         house                    rk excelo  sector 12   0.60
# 1393         house                  independent  sector 28   4.50
# 1455         house     unitech uniworld resorts  sector 33  10.00
# 1480         house                  independent  sector 17   3.50
# 1563         house       emaar the palm springs  sector 54  24.00
# 1679         house                  independent   sector 4   0.60
# 1884         house                  independent  sector 12   6.00
# 2492         house               uppal southend  sector 49   6.75
# 2524         house                dlf the grove  sector 54   5.70
# 2689         house     unitech uniworld resorts  sector 33   9.50
# 2758          flat           ambience caitriona  sector 24  14.00
# 2816         house                  independent  sector 54   3.75
# 2839         house       dlf city plots phase 2  sector 25  10.50
# 2857         house         eros rosewood villas  sector 49   2.75
# 2977         house                  independent  sector 55   1.45
# 2984         house          huda plot sector 38  sector 38   4.30
# 3328         house                  independent  sector 24  10.00
# 3408         house       unitech deerwood chase  sector 50   8.45
# 3532         house       dlf city plots phase 2  sector 25  10.00
# 3547         house                   ardee city  sector 52   5.50
# 3664         house           vipul tatvam villa  sector 48   7.25
#
#       price_per_sqft   area  \
# 107         126865.0   67.0
# 243         194444.0  360.0
# 276         266666.0  300.0
# 344         230547.0  347.0
# 456         161849.0  173.0
# 600         283333.0  251.0
# 686         308333.0   60.0
# 804         133079.0  263.0
# 1323        120000.0   50.0
# 1393        125000.0  360.0
# 1455        181818.0  550.0
# 1480        218750.0  160.0
# 1563        600000.0  400.0
# 1679        105263.0   57.0
# 1884        315789.0  190.0
# 2492        290948.0  232.0
# 2524        211111.0  270.0
# 2689        173992.0  546.0
# 2758        200000.0  700.0
# 2816        234375.0  160.0
# 2839        261194.0  402.0
# 2857        178571.0  154.0
# 2977        241666.0   60.0
# 2984        245398.0  175.0
# 3328        229885.0  435.0
# 3408        235376.0  359.0
# 3532        400000.0  250.0
# 3547        183333.0  300.0
# 3664        201388.0  360.0
#
#                                            areaWithType  super_built_up_area  \
# 107                            Plot area 67(6.22 sq.m.)                  NaN
# 243   Plot area 360(33.45 sq.m.)Built Up area: 3900 ...                  NaN
# 276                          Plot area 300(27.87 sq.m.)                  NaN
# 344   Built Up area: 347 (32.24 sq.m.)Carpet area: 2...                  NaN
# 456   Plot area 173(16.07 sq.m.)Built Up area: 160 s...                  NaN
# 600                           Plot area 240(22.3 sq.m.)                  NaN
# 686                            Plot area 60(5.57 sq.m.)                  NaN
# 804   Plot area 263(24.43 sq.m.)Built Up area: 4800 ...                  NaN
# 1323  Plot area 50(4.65 sq.m.)Built Up area: 30 sq.f...                  NaN
# 1393                   Built Up area: 360 (33.45 sq.m.)                  NaN
# 1455                          Plot area 550(51.1 sq.m.)                  NaN
# 1480                   Built Up area: 160 (14.86 sq.m.)                  NaN
# 1563                         Plot area 400(37.16 sq.m.)                  NaN
# 1679                            Plot area 57(5.3 sq.m.)                  NaN
# 1884  Plot area 190(17.65 sq.m.)Carpet area: 1600 sq...                  NaN
# 2492                         Plot area 232(21.55 sq.m.)                  NaN
# 2524                   Built Up area: 270 (25.08 sq.m.)                  NaN
# 2689                         Plot area 546(50.73 sq.m.)                  NaN
# 2758                   Built Up area: 700 (65.03 sq.m.)                  NaN
# 2816                         Plot area 160(14.86 sq.m.)                  NaN
# 2839                         Plot area 402(37.35 sq.m.)                  NaN
# 2857  Plot area 154(14.31 sq.m.)Carpet area: 1650 sq...                  NaN
# 2977                           Plot area 60(5.57 sq.m.)                  NaN
# 2984  Plot area 163(15.14 sq.m.)Built Up area: 145 s...                  NaN
# 3328                     Carpet area: 435 (40.41 sq.m.)                  NaN
# 3408                         Plot area 359(33.35 sq.m.)                  NaN
# 3532                         Plot area 250(23.23 sq.m.)                  NaN
# 3547                         Plot area 300(27.87 sq.m.)                  NaN
# 3664                         Plot area 360(33.45 sq.m.)                  NaN
#
#       built_up_area  carpet_area
# 107            67.0          NaN
# 243          3900.0       3743.0
# 276           300.0          NaN
# 344           347.0        215.0
# 456           160.0        150.0
# 600           240.0          NaN
# 686            60.0          NaN
# 804          4800.0       4400.0
# 1323           30.0         15.0
# 1393          360.0          NaN
# 1455          550.0          NaN
# 1480          160.0          NaN
# 1563          400.0          NaN
# 1679           57.0          NaN
# 1884            NaN       1600.0
# 2492          232.0          NaN
# 2524          270.0          NaN
# 2689          546.0          NaN
# 2758          700.0          NaN
# 2816          160.0          NaN
# 2839          402.0          NaN
# 2857            NaN       1650.0
# 2977           60.0          NaN
# 2984          145.0          NaN
# 3328            NaN        435.0
# 3408          359.0          NaN
# 3532          250.0          NaN
# 3547          300.0          NaN
# 3664          360.0          NaN

# %%
df.head()
# Out:
#   property_type                      society      sector  price  \
# 0          flat                 ss residency    sector 6   0.48
# 1          flat  ansal housing highland park  sector 103   1.10
# 2          flat        sapphire eighty three   sector 83   0.65
# 3          flat       unitech the residences   sector 33   1.35
# 4          flat                  m3m capital  sector 113   3.25
#
#    price_per_sqft    area                                       areaWithType  \
# 0          5333.0   900.0                     Carpet area: 100 (83.61 sq.m.)
# 1          6242.0  1762.0  Super Built up area 1762(163.7 sq.m.)Built Up ...
# 2          9286.0   700.0                   Built Up area: 700 (65.03 sq.m.)
# 3          8737.0  1545.0             Super Built up area 1545(143.54 sq.m.)
# 4         14142.0  2298.0                   Carpet area: 2298 (213.49 sq.m.)
#
#    bedRoom  bathroom balcony  floorNum      facing       agePossession  \
# 0        3         2       2       2.0         NaN      Moderately Old
# 1        3         3      3+       7.0  North-East        New Property
# 2        1         1       0       6.0         NaN           Undefined
# 3        3         4       2       8.0  North-East      Moderately Old
# 4        4         4      3+      34.0         NaN  Under Construction
#
#    super_built_up_area  built_up_area  carpet_area  study room  servant room  \
# 0                  NaN            NaN        100.0           0             0
# 1               1762.0         1500.0       1300.0           0             0
# 2                  NaN          700.0          NaN           0             0
# 3               1545.0            NaN          NaN           0             1
# 4                  NaN            NaN       2298.0           1             1
#
#    store room  pooja room  others  furnishing_type  luxury_score
# 0           0           0       0                0            54
# 1           0           0       0                0            87
# 2           0           0       0                0             0
# 3           0           0       0                0            49
# 4           0           1       0                0           115

# %%
sns.heatmap(pd.crosstab(df['property_type'],df['bedRoom']))
# Out:
# <Axes: xlabel='bedRoom', ylabel='property_type'>

# %%
# checking outliers
df[df['bedRoom'] >= 10]
# Out:
#      property_type                      society      sector  price  \
# 45           house  independent house sector 45   sector 40   9.00
# 47           house                  independent  sector 17a   3.93
# 78           house       luxury dlf city floors   sector 26   8.25
# 131          house                  independent   sector 26  14.75
# 134          house                  independent   sector 55   7.49
# ...            ...                          ...         ...    ...
# 3699         house                  independent   sector 46   6.50
# 3727         house               uppal southend   sector 49   6.75
# 3752         house                  independent   sector 26  10.50
# 3769         house               uppal southend   sector 49   6.75
# 3785         house                  independent   sector 27   8.25
#
#       price_per_sqft    area  \
# 45           38022.0  2367.0
# 47           24214.0  1623.0
# 78           45833.0  1800.0
# 131          51864.0  2844.0
# 134          27741.0  2700.0
# ...              ...     ...
# 3699         27461.0  2367.0
# 3727         31915.0  2115.0
# 3752         43210.0  2430.0
# 3769         32328.0  2088.0
# 3785         45833.0  1800.0
#
#                                            areaWithType  bedRoom  bathroom  \
# 45    Plot area 2367(219.9 sq.m.)Built Up area: 9000...       12        12
# 47    Plot area 1623(150.78 sq.m.)Built Up area: 162...       19        17
# 78                          Plot area 200(167.23 sq.m.)       12        12
# 131                         Plot area 316(264.22 sq.m.)       16        20
# 134                         Plot area 300(250.84 sq.m.)       12        12
# ...                                                 ...      ...       ...
# 3699                         Plot area 263(219.9 sq.m.)       12        12
# 3727                        Plot area 235(196.49 sq.m.)       12        12
# 3752  Plot area 302(252.51 sq.m.)Built Up area: 300 ...       12        12
# 3769                        Plot area 232(193.98 sq.m.)       12        12
# 3785  Plot area 210(175.59 sq.m.)Built Up area: 205 ...       12        12
#
#      balcony  floorNum      facing   agePossession  super_built_up_area  \
# 45         3       4.0  North-West    New Property                  NaN
# 47         3       4.0  North-West  Relatively New                  NaN
# 78        3+       4.0       North    New Property                  NaN
# 131       3+       4.0        East    New Property                  NaN
# 134       3+       4.0  South-East  Relatively New                  NaN
# ...      ...       ...         ...             ...                  ...
# 3699      3+       4.0  North-West  Relatively New                  NaN
# 3727      3+       3.0        West  Moderately Old                  NaN
# 3752      3+       4.0  North-East  Relatively New                  NaN
# 3769      3+       3.0       North  Moderately Old                  NaN
# 3785      3+       4.0        East    New Property                  NaN
#
#       built_up_area  carpet_area  study room  servant room  store room  \
# 45           9000.0       6000.0           0             1           0
# 47           1622.0          NaN           1             1           1
# 78            200.0          NaN           0             1           0
# 131           316.0          NaN           1             1           1
# 134           300.0          NaN           1             1           0
# ...             ...          ...         ...           ...         ...
# 3699          263.0          NaN           1             0           0
# 3727          235.0          NaN           0             0           0
# 3752          300.0        270.0           0             1           0
# 3769          232.0          NaN           1             1           0
# 3785          205.0        200.0           0             1           0
#
#       pooja room  others  furnishing_type  luxury_score
# 45             0       0                1            71
# 47             1       0                0            74
# 78             0       0                1           105
# 131            1       0                1           153
# 134            1       0                1            49
# ...          ...     ...              ...           ...
# 3699           1       0                1            32
# 3727           0       1                0            49
# 3752           1       0                1            72
# 3769           1       1                1            49
# 3785           1       0                1            40
#
# [72 rows x 23 columns]

# %%
sns.barplot(x=df['property_type'],y=df['floorNum'])
# Out:
# <Axes: xlabel='property_type', ylabel='floorNum'>

# %%
sns.boxplot(x=df['property_type'],y=df['floorNum'])
# Out:
# <Axes: xlabel='property_type', ylabel='floorNum'>

# %%
# checking for outliers
df[(df['property_type'] == 'house') & (df['floorNum'] > 10)]
# Out:
#      property_type                  society      sector  price  \
# 410          house              greenopolis   sector 89   0.70
# 501          house          godrej meridien  sector 106   5.60
# 780          house           ats tourmaline  sector 109   1.87
# 811          house  indiabulls centrum park  sector 103   3.25
# 988          house              spaze privy   sector 72   3.09
# 1057         house      ireo victory valley   sector 67   8.00
# 1251         house   vatika the seven lamps   sector 82   1.60
# 1361         house              spaze privy   sector 72   3.10
# 1687         house      satya the hermitage  sector 103   3.15
# 2110         house        suncity avenue 76   sector 76   0.75
# 2423         house           dlf the arbour   sector 63   8.50
# 3038         house              independent   sector 92   1.80
# 3147         house               ninex city   sector 76   1.75
# 3519         house         suncity township   sector 54   2.00
#
#       price_per_sqft    area  \
# 410           5397.0  1297.0
# 501          14000.0  4000.0
# 780           8697.0  2150.0
# 811           8125.0  4000.0
# 988           6981.0  4426.0
# 1057         22222.0  3600.0
# 1251          6597.0  2425.0
# 1361          8486.0  3653.0
# 1687          6702.0  4700.0
# 2110         10067.0   745.0
# 2423         21519.0  3950.0
# 3038          7627.0  2360.0
# 3147          6250.0  2800.0
# 3519         30968.0   646.0
#
#                                            areaWithType  bedRoom  bathroom  \
# 410                   Built Up area: 1297 (120.5 sq.m.)        2         2
# 501                        Plot area 4000(371.61 sq.m.)        5         4
# 780                  Built Up area: 2150 (199.74 sq.m.)        3         4
# 811                        Plot area 4000(371.61 sq.m.)        4         3
# 988   Built Up area: 3653 (339.37 sq.m.)Carpet area:...        5         5
# 1057                        Plot area 400(334.45 sq.m.)        6         7
# 1251                       Plot area 2425(225.29 sq.m.)        4         4
# 1361                       Plot area 3653(339.37 sq.m.)        5         5
# 1687                 Built Up area: 4700 (436.64 sq.m.)        4         5
# 2110  Plot area 745(69.21 sq.m.)Built Up area: 745 s...        2         2
# 2423                 Built Up area: 3950 (366.97 sq.m.)        4         4
# 3038                 Built Up area: 2360 (219.25 sq.m.)        4         5
# 3147                   Carpet area: 2800 (260.13 sq.m.)        4         4
# 3519  Plot area 60Built Up area: 60 sq.m.Carpet area...        9         9
#
#      balcony  floorNum      facing       agePossession  super_built_up_area  \
# 410        2      14.0  North-East           Undefined                  NaN
# 501       3+      33.0  North-East        New Property                  NaN
# 780        0      12.0         NaN           Undefined                  NaN
# 811       3+      20.0         NaN  Under Construction                  NaN
# 988       3+      14.0        East      Relatively New                  NaN
# 1057      3+      51.0  North-East      Moderately Old                  NaN
# 1251      3+      16.0       North      Moderately Old                  NaN
# 1361      3+      21.0         NaN      Relatively New                  NaN
# 1687       0      12.0        East           Undefined                  NaN
# 2110       2      11.0  North-East        New Property                  NaN
# 2423      3+      27.0         NaN           Undefined                  NaN
# 3038       0      13.0         NaN           Undefined                  NaN
# 3147       0      14.0         NaN           Undefined                  NaN
# 3519       3      11.0       North      Relatively New                  NaN
#
#       built_up_area  carpet_area  study room  servant room  store room  \
# 410          1297.0          NaN           0             0           0
# 501          4000.0          NaN           1             1           1
# 780          2150.0          NaN           0             0           0
# 811          4000.0          NaN           0             0           0
# 988          3653.0       2922.0           0             1           0
# 1057          400.0          NaN           1             1           0
# 1251         2425.0          NaN           0             1           0
# 1361         3653.0          NaN           0             0           0
# 1687         4700.0          NaN           0             0           0
# 2110          745.0          NaN           0             0           0
# 2423         3950.0          NaN           0             0           0
# 3038         2360.0          NaN           0             0           0
# 3147            NaN       2800.0           0             0           0
# 3519           60.0         59.0           0             1           0
#
#       pooja room  others  furnishing_type  luxury_score
# 410            0       0                0             0
# 501            1       0                0           151
# 780            0       0                0             0
# 811            0       0                0            51
# 988            0       0                1            33
# 1057           1       0                1            49
# 1251           0       0                0            94
# 1361           0       0                0             0
# 1687           0       0                0            61
# 2110           0       0                0            40
# 2423           0       0                0            61
# 3038           0       0                0             0
# 3147           0       0                0             0
# 3519           0       0                2             7

# %% [markdown]
# #### conclusion -  houses(villa) but in appartments

# %%
df.head()
# Out:
#   property_type                      society      sector  price  \
# 0          flat                 ss residency    sector 6   0.48
# 1          flat  ansal housing highland park  sector 103   1.10
# 2          flat        sapphire eighty three   sector 83   0.65
# 3          flat       unitech the residences   sector 33   1.35
# 4          flat                  m3m capital  sector 113   3.25
#
#    price_per_sqft    area                                       areaWithType  \
# 0          5333.0   900.0                     Carpet area: 100 (83.61 sq.m.)
# 1          6242.0  1762.0  Super Built up area 1762(163.7 sq.m.)Built Up ...
# 2          9286.0   700.0                   Built Up area: 700 (65.03 sq.m.)
# 3          8737.0  1545.0             Super Built up area 1545(143.54 sq.m.)
# 4         14142.0  2298.0                   Carpet area: 2298 (213.49 sq.m.)
#
#    bedRoom  bathroom balcony  floorNum      facing       agePossession  \
# 0        3         2       2       2.0         NaN      Moderately Old
# 1        3         3      3+       7.0  North-East        New Property
# 2        1         1       0       6.0         NaN           Undefined
# 3        3         4       2       8.0  North-East      Moderately Old
# 4        4         4      3+      34.0         NaN  Under Construction
#
#    super_built_up_area  built_up_area  carpet_area  study room  servant room  \
# 0                  NaN            NaN        100.0           0             0
# 1               1762.0         1500.0       1300.0           0             0
# 2                  NaN          700.0          NaN           0             0
# 3               1545.0            NaN          NaN           0             1
# 4                  NaN            NaN       2298.0           1             1
#
#    store room  pooja room  others  furnishing_type  luxury_score
# 0           0           0       0                0            54
# 1           0           0       0                0            87
# 2           0           0       0                0             0
# 3           0           0       0                0            49
# 4           0           1       0                0           115

# %%
sns.heatmap(pd.crosstab(df['property_type'],df['agePossession']))
# Out:
# <Axes: xlabel='agePossession', ylabel='property_type'>

# %%
sns.heatmap(pd.pivot_table(df,index='property_type',columns='agePossession',values='price',aggfunc='mean'),annot=True)
# Out:
# <Axes: xlabel='agePossession', ylabel='property_type'>

# %%
plt.figure(figsize=(15,4))
sns.heatmap(pd.pivot_table(df,index='property_type',columns='bedRoom',values='price',aggfunc='mean'),annot=True)
# Out:
# <Axes: xlabel='bedRoom', ylabel='property_type'>

# %%
sns.heatmap(pd.crosstab(df['property_type'],df['furnishing_type']))
# Out:
# <Axes: xlabel='furnishing_type', ylabel='property_type'>

# %%
sns.heatmap(pd.pivot_table(df,index='property_type',columns='furnishing_type',values='price',aggfunc='mean'),annot=True)
# Out:
# <Axes: xlabel='furnishing_type', ylabel='property_type'>

# %%
sns.barplot(x=df['property_type'],y=df['luxury_score'])
# Out:
# <Axes: xlabel='property_type', ylabel='luxury_score'>

# %%
sns.boxplot(x=df['property_type'],y=df['luxury_score'])
# Out:
# <Axes: xlabel='property_type', ylabel='luxury_score'>

# %%
df.head()
# Out:
#   property_type                      society      sector  price  \
# 0          flat                 ss residency    sector 6   0.48
# 1          flat  ansal housing highland park  sector 103   1.10
# 2          flat        sapphire eighty three   sector 83   0.65
# 3          flat       unitech the residences   sector 33   1.35
# 4          flat                  m3m capital  sector 113   3.25
#
#    price_per_sqft    area                                       areaWithType  \
# 0          5333.0   900.0                     Carpet area: 100 (83.61 sq.m.)
# 1          6242.0  1762.0  Super Built up area 1762(163.7 sq.m.)Built Up ...
# 2          9286.0   700.0                   Built Up area: 700 (65.03 sq.m.)
# 3          8737.0  1545.0             Super Built up area 1545(143.54 sq.m.)
# 4         14142.0  2298.0                   Carpet area: 2298 (213.49 sq.m.)
#
#    bedRoom  bathroom balcony  floorNum      facing       agePossession  \
# 0        3         2       2       2.0         NaN      Moderately Old
# 1        3         3      3+       7.0  North-East        New Property
# 2        1         1       0       6.0         NaN           Undefined
# 3        3         4       2       8.0  North-East      Moderately Old
# 4        4         4      3+      34.0         NaN  Under Construction
#
#    super_built_up_area  built_up_area  carpet_area  study room  servant room  \
# 0                  NaN            NaN        100.0           0             0
# 1               1762.0         1500.0       1300.0           0             0
# 2                  NaN          700.0          NaN           0             0
# 3               1545.0            NaN          NaN           0             1
# 4                  NaN            NaN       2298.0           1             1
#
#    store room  pooja room  others  furnishing_type  luxury_score
# 0           0           0       0                0            54
# 1           0           0       0                0            87
# 2           0           0       0                0             0
# 3           0           0       0                0            49
# 4           0           1       0                0           115

# %%
# sector analysis
plt.figure(figsize=(15,6))
sns.heatmap(pd.crosstab(df['property_type'],df['sector'].sort_index()))
# Out:
# <Axes: xlabel='sector', ylabel='property_type'>

# %%
# sector analysis
import re
# Group by 'sector' and calculate the average price
avg_price_per_sector = df.groupby('sector')['price'].mean().reset_index()

# Function to extract sector numbers
def extract_sector_number(sector_name):
    match = re.search(r'\d+', sector_name)
    if match:
        return int(match.group())
    else:
        return float('inf')  # Return a large number for non-numbered sectors

avg_price_per_sector['sector_number'] = avg_price_per_sector['sector'].apply(extract_sector_number)

# Sort by sector number
avg_price_per_sector_sorted_by_sector = avg_price_per_sector.sort_values(by='sector_number')

# Plot the heatmap
plt.figure(figsize=(5, 25))
sns.heatmap(avg_price_per_sector_sorted_by_sector.set_index('sector')[['price']], annot=True, fmt=".2f", linewidths=.5)
plt.title('Average Price per Sector (Sorted by Sector Number)')
plt.xlabel('Average Price')
plt.ylabel('Sector')
plt.show()

# %%
avg_price_per_sqft_sector = df.groupby('sector')['price_per_sqft'].mean().reset_index()

avg_price_per_sqft_sector['sector_number'] = avg_price_per_sqft_sector['sector'].apply(extract_sector_number)

# Sort by sector number
avg_price_per_sqft_sector_sorted_by_sector = avg_price_per_sqft_sector.sort_values(by='sector_number')

# Plot the heatmap
plt.figure(figsize=(5, 25))
sns.heatmap(avg_price_per_sqft_sector_sorted_by_sector.set_index('sector')[['price_per_sqft']], annot=True, fmt=".2f", linewidths=.5)
plt.title('Sector (Sorted by Sector Number)')
plt.xlabel('Average Price per sqft')
plt.ylabel('Sector')
plt.show()

# %%
luxury_score = df.groupby('sector')['luxury_score'].mean().reset_index()

luxury_score['sector_number'] = luxury_score['sector'].apply(extract_sector_number)

# Sort by sector number
luxury_score_sector = luxury_score.sort_values(by='sector_number')

# Plot the heatmap
plt.figure(figsize=(5, 25))
sns.heatmap(luxury_score_sector.set_index('sector')[['luxury_score']], annot=True, fmt=".2f", linewidths=.5)
plt.title('Sector (Sorted by Sector Number)')
plt.xlabel('Average Price per sqft')
plt.ylabel('Sector')
plt.show()

# %%
df.head()
# Out:
#   property_type                      society      sector  price  \
# 0          flat                 ss residency    sector 6   0.48
# 1          flat  ansal housing highland park  sector 103   1.10
# 2          flat        sapphire eighty three   sector 83   0.65
# 3          flat       unitech the residences   sector 33   1.35
# 4          flat                  m3m capital  sector 113   3.25
#
#    price_per_sqft    area                                       areaWithType  \
# 0          5333.0   900.0                     Carpet area: 100 (83.61 sq.m.)
# 1          6242.0  1762.0  Super Built up area 1762(163.7 sq.m.)Built Up ...
# 2          9286.0   700.0                   Built Up area: 700 (65.03 sq.m.)
# 3          8737.0  1545.0             Super Built up area 1545(143.54 sq.m.)
# 4         14142.0  2298.0                   Carpet area: 2298 (213.49 sq.m.)
#
#    bedRoom  bathroom balcony  floorNum      facing       agePossession  \
# 0        3         2       2       2.0         NaN      Moderately Old
# 1        3         3      3+       7.0  North-East        New Property
# 2        1         1       0       6.0         NaN           Undefined
# 3        3         4       2       8.0  North-East      Moderately Old
# 4        4         4      3+      34.0         NaN  Under Construction
#
#    super_built_up_area  built_up_area  carpet_area  study room  servant room  \
# 0                  NaN            NaN        100.0           0             0
# 1               1762.0         1500.0       1300.0           0             0
# 2                  NaN          700.0          NaN           0             0
# 3               1545.0            NaN          NaN           0             1
# 4                  NaN            NaN       2298.0           1             1
#
#    store room  pooja room  others  furnishing_type  luxury_score
# 0           0           0       0                0            54
# 1           0           0       0                0            87
# 2           0           0       0                0             0
# 3           0           0       0                0            49
# 4           0           1       0                0           115

# %% [markdown]
# ## price

# %%
sns.scatterplot(
    x = df[df['area'] < 10000]['area'],
    y = df[df['area'] < 10000]['price'],
    hue = df[df['area'] < 10000]['bedRoom']
)
# Out:
# <Axes: xlabel='area', ylabel='price'>

# %%
plt.figure(figsize=(12, 8))

filtered_df = df[df['area'] < 10000]
sns.scatterplot(
    x=filtered_df['area'],
    y=filtered_df['price'],
    hue=filtered_df['agePossession']
)
# Out:
# <Axes: xlabel='area', ylabel='price'>

# %%
plt.figure(figsize=(12, 8))

filtered_df = df[df['area'] < 10000]

sns.scatterplot(
    x=filtered_df['area'],
    y=filtered_df['price'],
    hue=filtered_df['furnishing_type'].astype('category')  # Cast to category if needed
)
# Out:
# <Axes: xlabel='area', ylabel='price'>

# %%
sns.barplot(x=df['bedRoom'],y=df['price'],estimator=np.median)
# Out:
# <Axes: xlabel='bedRoom', ylabel='price'>

# %%
sns.barplot(x=df['agePossession'],y=df['price'],estimator=np.median)
plt.xticks(rotation='vertical')
plt.show()

# %%
sns.barplot(x=df['agePossession'],y=df['area'],estimator=np.median)
plt.xticks(rotation='vertical')
plt.show()

# %%
sns.barplot(x=df['furnishing_type'],y=df['price'],estimator=np.median)
# Out:
# <Axes: xlabel='furnishing_type', ylabel='price'>

# %%
sns.scatterplot(
    x = df['luxury_score'],
    y = df['price']
)
# Out:
# <Axes: xlabel='luxury_score', ylabel='price'>

# %% [markdown]
# ## correlation

# %%
numeric_df = df.select_dtypes(include='number')

plt.figure(figsize=(8, 8))
sns.heatmap(numeric_df.corr(), annot=False, cmap='magma')  # Or just remove annot
# Out:
# <Axes: >

# %%
df.select_dtypes(include='number').corr()['price'].sort_values(ascending=False)
# Out:
# price                  1.000000
# super_built_up_area    0.769412
# bathroom               0.589826
# bedRoom                0.522925
# servant room           0.400927
# price_per_sqft         0.391251
# pooja room             0.341492
# store room             0.309121
# study room             0.258602
# furnishing_type        0.253680
# luxury_score           0.094775
# built_up_area          0.052254
# area                   0.034720
# others                -0.003525
# carpet_area           -0.011344
# floorNum              -0.094290
# Name: price, dtype: float64

# %%
df.head()
# Out:
#   property_type                      society      sector  price  \
# 0          flat                 ss residency    sector 6   0.48
# 1          flat  ansal housing highland park  sector 103   1.10
# 2          flat        sapphire eighty three   sector 83   0.65
# 3          flat       unitech the residences   sector 33   1.35
# 4          flat                  m3m capital  sector 113   3.25
#
#    price_per_sqft    area                                       areaWithType  \
# 0          5333.0   900.0                     Carpet area: 100 (83.61 sq.m.)
# 1          6242.0  1762.0  Super Built up area 1762(163.7 sq.m.)Built Up ...
# 2          9286.0   700.0                   Built Up area: 700 (65.03 sq.m.)
# 3          8737.0  1545.0             Super Built up area 1545(143.54 sq.m.)
# 4         14142.0  2298.0                   Carpet area: 2298 (213.49 sq.m.)
#
#    bedRoom  bathroom balcony  floorNum      facing       agePossession  \
# 0        3         2       2       2.0         NaN      Moderately Old
# 1        3         3      3+       7.0  North-East        New Property
# 2        1         1       0       6.0         NaN           Undefined
# 3        3         4       2       8.0  North-East      Moderately Old
# 4        4         4      3+      34.0         NaN  Under Construction
#
#    super_built_up_area  built_up_area  carpet_area  study room  servant room  \
# 0                  NaN            NaN        100.0           0             0
# 1               1762.0         1500.0       1300.0           0             0
# 2                  NaN          700.0          NaN           0             0
# 3               1545.0            NaN          NaN           0             1
# 4                  NaN            NaN       2298.0           1             1
#
#    store room  pooja room  others  furnishing_type  luxury_score
# 0           0           0       0                0            54
# 1           0           0       0                0            87
# 2           0           0       0                0             0
# 3           0           0       0                0            49
# 4           0           1       0                0           115

# %%
sns.pairplot(df)
